# %% [markdown]
# <a href="https://colab.research.google.com/github/rachabav/coursera-training/blob/AI-module1/ProgrammaticPrompting1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !!pip install litellm

# Important!!!
#
# <---- Set your 'OPENAI_API_KEY' as a secret over there with the "key" icon
#
#
import os
from google.colab import userdata

# --- BARE MINIMUM ADAPTATION START ---
# Change the key name to the one for Gemini/LiteLLM
api_key = userdata.get('GEMINI_API_KEY')
os.environ['GEMINI_API_KEY'] = api_key
# --- BARE MINIMUM ADAPTATION END ---

# %%
#
# Set your API key as shown in the Google Colab notebook
#

from litellm import completion
from typing import List, Dict


def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="gemini/gemini-2.5-flash", # Use a Gemini model name
        messages=messages,
        max_tokens=1024
    )
    return response.choices[0].message.content


messages = [
    {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
    {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response)
# Out:
# None

# %%
import litellm

# The model name must be prefixed with 'gemini/' for LiteLLM to route correctly.
# Common models are: 'gemini/gemini-2.5-flash', 'gemini/gemini-2.5-pro', etc.

try:
    response = litellm.completion(
        # --- BARE MINIMUM ADAPTATION START ---
        model="gemini/gemini-2.5-flash", # Use a Gemini model name
        # --- BARE MINIMUM ADAPTATION END ---
        messages=[
           {
               "role": "user",
              #  "content": "Explain the importance of the environment variable GEMINI_API_KEY."
               "content": "Describe the concept of 'black box optimization' and provide a real-world example of where it is commonly applied in engineering."
              #  "content": "Write a short Python function that calculates the Levenshtein distance between two strings, and explain its time complexity."
           }
        ],
        temperature=0.3
    )

    # Accessing the content is the same as the OpenAI example
    print(response.choices[0].message.content)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# ## Black Box Optimization: The Concept
#
# **Black box optimization** refers to the process of finding the optimal inputs for a system where the internal workings or mathematical model of that system are unknown, inaccessible, or too complex to be represented analytically. In essence, you treat the system like a "black box": you can feed it inputs, observe its outputs, but you cannot "look inside" to understand *how* it transforms those inputs into outputs.
#
# Here's a breakdown of the concept:
#
# 1.  **The "Black Box":**
#     *   **Unknown Internal Structure:** You don't have a mathematical equation ($f(x) = y$) that describes the relationship between inputs ($x$) and outputs ($y$).
#     *   **No Gradient Information:** Because there's no explicit function, you cannot calculate derivatives (gradients) which are crucial for many traditional optimization algorithms (like gradient descent).
#     *   **Evaluation Only:** The only way to understand the system's behavior is to provide inputs and observe the resulting output. This evaluation often involves running a physical experiment, a complex simulation, or executing a proprietary piece of software.
#
# 2.  **The "Optimization":**
#     *   **Goal:** To find the set of input parameters ($x$) that maximizes or minimizes a specific output ($y$) or a combination of outputs, subject to certain constraints.
#     *   **Iterative Process:** Since there's no direct path to the optimum, black box optimization algorithms work iteratively. They propose a set of inputs, evaluate the black box, observe the performance, and then use that information to intelligently propose a *new* set of inputs that are likely to perform better.
#     *   **Derivative-Free Methods:** These algorithms rely on sampling, heuristics, and statistical models rather than calculus. Common approaches include:
#         *   **Evolutionary Algorithms:** Genetic Algorithms, Evolutionary Strategies, Particle Swarm Optimization.
#         *   **Bayesian Optimization:** Builds a probabilistic model of the black box function to guide sampling.
#         *   **Simulated Annealing:** Explores the search space by accepting worse solutions with a decreasing probability.
#         *   **Random Search/Grid Search:** Simpler, less efficient but sometimes effective for low-dimensional problems.
#
# 3.  **Key Characteristics & Challenges:**
#     *   **Expensive Evaluations:** Often, evaluating the black box is time-consuming, resource-intensive, or costly (e.g., running a physical test, a high-fidelity simulation). This makes the number of evaluations a critical constraint.
#     *   **Noisy Outputs:** The output of the black box might be subject to random noise, making it harder to discern true improvements.
#     *   **High Dimensionality:** As the number of input parameters increases, the search space grows exponentially, making optimization much harder.
#     *   **Exploration vs. Exploitation:** Algorithms must balance exploring new, unknown regions of the input space with exploiting regions that have already shown promising results.
#
# ## Real-World Engineering Example: Engine Calibration in Automotive Engineering
#
# A prime example of black box optimization in engineering is **engine calibration** for internal combustion engines (and increasingly, electric powertrains).
#
# **The Scenario:**
# Automotive engineers need to tune an engine to achieve optimal performance across multiple objectives:
# *   **Maximize:** Fuel efficiency, power output, torque.
# *   **Minimize:** Emissions (NOx, CO, particulates), engine noise, vibrations.
# *   **Ensure:** Durability, drivability, compliance with regulations.
#
# **The "Black Box":**
# The engine itself, or a highly complex, high-fidelity engine simulation model.
# *   **Inputs (Control Parameters):**
#     *   Fuel injection timing and quantity
#     *   Spark timing
#     *   Air-fuel ratio
#     *   Turbocharger boost pressure
#     *   Variable valve timing
#     *   EGR (Exhaust Gas Recirculation) rates
#     *   Throttle body position
#     *   And many more, often hundreds of parameters, which can vary with engine speed, load, and temperature.
# *   **Outputs (Performance Metrics):**
#     *   Measured fuel consumption
#     *   Measured power and torque on a dynamometer
#     *   Measured exhaust gas emissions
#     *   Noise levels
#     *   Engine temperature profiles
#
# **Why it's Black Box Optimization:**
# 1.  **No Analytical Model:** There's no simple set of equations that can accurately predict fuel consumption, emissions, or power output as a direct, differentiable function of all these complex, interacting control parameters. The physics of combustion, fluid dynamics, and thermodynamics are incredibly complex and non-linear.
# 2.  **Expensive Evaluations:**
#     *   **Physical Testing:** Running an engine on a test bench (dynamometer) is extremely expensive, time-consuming, and requires specialized equipment and personnel. Each test run for a specific set of parameters can take hours.
#     *   **High-Fidelity Simulation:** While faster than physical tests, these simulations (e.g., CFD models for combustion) are still computationally intensive, taking minutes to hours for a single evaluation, and they don't provide analytical gradients.
# 3.  **High Dimensionality:** With hundreds of parameters to tune, the search space is astronomically large.
#
# **How Black Box Optimization is Applied:**
# Engineers use black box optimization algorithms (often Bayesian Optimization, Genetic Algorithms, or Response Surface Methodology) to intelligently explore this vast parameter space.
#
# 1.  **Initial Sampling:** The algorithm starts by suggesting a few initial combinations of control parameters.
# 2.  **Evaluation:** These parameter sets are then applied to the physical engine on a test bench or fed into the high-fidelity simulation. The performance metrics (fuel efficiency, emissions, power) are measured.
# 3.  **Learning and Suggestion:** The optimization algorithm analyzes the results. It builds an internal model (a "surrogate model" or "response surface") of how the inputs relate to the outputs, even without knowing the true underlying physics. Based on this model and its uncertainty, it suggests the *next* most promising set of parameters to test, aiming to either improve performance or reduce uncertainty in unexplored regions.
# 4.  **Iteration:** This process repeats, iteratively refining the parameter settings until an optimal (or near-optimal) calibration is found that balances all the conflicting objectives.
#
# By using black box optimization, automotive engineers can significantly reduce the time and cost of engine development, find better operating points than manual tuning, and meet increasingly stringent performance and environmental regulations.

# %% [markdown]
# <a href="https://colab.research.google.com/github/rachabav/coursera-training/blob/AI-module1/ProgrammaticPrompting1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !!pip install litellm

# Important!!!
#
# <---- Set your 'GEMINI_API_KEY' as a secret over there with the "key" icon
#
#
import os
from google.colab import userdata

# --- BARE MINIMUM ADAPTATION START ---
# Change the key name to the one for Gemini/LiteLLM
api_key = userdata.get('GEMINI_API_KEY')
os.environ['GEMINI_API_KEY'] = api_key
# --- BARE MINIMUM ADAPTATION END ---

# %%
#
# Set your API key as shown in the Google Colab notebook
#

from litellm import completion
from typing import List, Dict


def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="gemini/gemini-2.5-flash", # Use a Gemini model name
        messages=messages,
        temperature=0.3,
        max_tokens=1024
    )
    return response.choices[0].message.content


messages = [
    {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
    {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response)
# Out:
# None

# %%
import litellm

# The model name must be prefixed with 'gemini/' for LiteLLM to route correctly.
# Common models are: 'gemini/gemini-2.5-flash', 'gemini/gemini-2.5-pro', etc.

try:
    response = litellm.completion(
        # --- BARE MINIMUM ADAPTATION START ---
        model="gemini/gemini-2.5-flash", # Use a Gemini model name
        # --- BARE MINIMUM ADAPTATION END ---
        messages=[
            {
                "role": "system",
                "content": "You are an expert software engineer that prefers functional programming."
            },
            {
               "role": "user",
               "content": "Write a function to swap the keys and values in a dictionary."
              #  "content": "Explain the importance of the environment variable GEMINI_API_KEY."
              #  "content": "Describe the concept of 'black box optimization' and provide a real-world example of where it is commonly applied in engineering."
              #  "content": "Write a short Python function that calculates the Levenshtein distance between two strings, and explain its time complexity."
           }
        ],
        temperature=0.3
    )

    # Accessing the content is the same as the OpenAI example
    print(response.choices[0].message.content)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# As an expert software engineer who prefers functional programming, the primary concern when swapping keys and values in a dictionary is how to handle potential duplicate values.
#
# If the original dictionary has multiple keys mapping to the *same* value (e.g., `{ "a": 1, "b": 1 }`), and we try to make that value a key, we'll have a collision because dictionary keys must be unique.
#
# There are a few common strategies for this:
#
# 1.  **Robust (Recommended for functional safety):** The new dictionary's values become a *list* of the original keys.
#     *   Example: `{ "a": 1, "b": 1, "c": 2 }` becomes `{ 1: ["a", "b"], 2: ["c"] }`
#     *   This preserves all information.
#
# 2.  **Simple (Potentially Lossy):** If a value appears multiple times, one of the original keys "wins" (e.g., the last one encountered).
#     *   Example: `{ "a": 1, "b": 1, "c": 2 }` becomes `{ 1: "b", 2: "c" }` (if "b" was processed after "a").
#     *   This loses information about "a".
#
# 3.  **Error (Explicit):** Throw an error if duplicate values are encountered.
#
# I'll provide a solution in F# for the **robust** approach, as it's generally preferred in functional programming to avoid data loss and side effects. I'll also show a simpler, potentially lossy version for completeness.
#
# ---
#
# ## F# Solution
#
# In F#, the `Map<'Key, 'Value>` type is an immutable dictionary, which aligns perfectly with functional principles.
#
# ```fsharp
# open System.Collections.Generic // For Dictionary if you prefer mutable, but Map is better
# open FSharp.Collections // For Map
#
# /// Swaps the keys and values of a Map.
# ///
# /// If multiple original keys map to the same value, the new Map will have
# /// that value as a key, and its corresponding value will be a list of
# /// all original keys that mapped to it.
# ///
# /// Type parameters:
# ///   'Key: The type of the original keys. Must be comparable.
# ///   'Value: The type of the original values. Must be comparable (as it becomes a key).
# ///
# /// Returns: A new Map where original values are keys, and original keys are lists of values.
# let swapKeysAndValuesRobust (inputMap: Map<'Key, 'Value>) : Map<'Value, list<'Key>> =
#     inputMap
#     // Convert the Map to a sequence of (key, value) pairs.
#     |> Map.toSeq
#     // Group the pairs by their 'value' (which will become the new key).
#     // `snd` extracts the second element of a tuple (the value).
#     |> Seq.groupBy snd
#     // For each group (oldValue, seqOfPairs):
#     //   - oldValue is the new key.
#     //   - seqOfPairs contains all (originalKey, oldValue) tuples that share this oldValue.
#     |> Seq.map (fun (oldValue, seqOfPairs) ->
#         // Extract just the original keys from the sequence of pairs,
#         // and convert them into a list.
#         let originalKeys = seqOfPairs |> Seq.map fst |> Seq.toList
#         // Return the new (key, value) pair for the result Map.
#         (oldValue, originalKeys)
#     )
#     // Convert the sequence of new (value, list<key>) pairs back into a Map.
#     |> Map.ofSeq
#
# /// A simpler, potentially lossy version of the swap.
# ///
# /// If multiple original keys map to the same value, only one of the original keys
# /// will be retained in the new Map (typically the last one processed).
# /// Use with caution if data loss is not acceptable.
# ///
# /// Type parameters:
# ///   'Key: The type of the original keys. Must be comparable.
# ///   'Value: The type of the original values. Must be comparable (as it becomes a key).
# ///
# /// Returns: A new Map where original values are keys, and original keys are values.
# let swapKeysAndValuesSimple (inputMap: Map<'Key, 'Value>) : Map<'Value, 'Key> =
#     inputMap
#     |> Map.toSeq
#     // Simply flip each (key, value) pair to (value, key).
#     |> Seq.map (fun (key, value) -> (value, key))
#     // Convert the sequence of flipped pairs back into a Map.
#     // If there are duplicate new keys (original values), Map.ofSeq will
#     // overwrite previous entries, resulting in data loss.
#     |> Map.ofSeq
#
# // --- Examples ---
#
# // Example 1: No duplicate values
# let map1 = Map.ofList [ ("a", 1); ("b", 2); ("c", 3) ]
# printfn "Original Map 1: %A" map1
# let swapped1Robust = swapKeysAndValuesRobust map1
# printfn "Swapped Map 1 (Robust): %A" swapped1Robust // Map [1, ["a"]; 2, ["b"]; 3, ["c"]]
# let swapped1Simple = swapKeysAndValuesSimple map1
# printfn "Swapped Map 1 (Simple): %A" swapped1Simple // Map [1, "a"; 2, "b"; 3, "c"]
#
# printfn "-------------------------------------"
#
# // Example 2: With duplicate values
# let map2 = Map.ofList [ ("apple", "fruit"); ("banana", "fruit"); ("carrot", "vegetable") ]
# printfn "Original Map 2: %A" map2
#
# let swapped2Robust = swapKeysAndValuesRobust map2
# // Expected: Map ["fruit", ["apple"; "banana"]; "vegetable", ["carrot"]]
# printfn "Swapped Map 2 (Robust): %A" swapped2Robust
#
# let swapped2Simple = swapKeysAndValuesSimple map2
# // Expected: Map ["fruit", "banana"; "vegetable", "carrot"] (assuming "banana" was processed after "apple")
# printfn "Swapped Map 2 (Simple): %A" swapped2Simple
#
# printfn "-------------------------------------"
#
# // Example 3: Empty Map
# let emptyMap = Map.empty<string, int>
# printfn "Original Empty Map: %A" emptyMap
# let swappedEmptyRobust = swapKeysAndValuesRobust emptyMap
# printfn "Swapped Empty Map (Robust): %A" swappedEmptyRobust // Map []
# let swappedEmptySimple = swapKeysAndValuesSimple emptyMap
# printfn "Swapped Empty Map (Simple): %A" swappedEmptySimple // Map []
# ```
#
# ### Explanation:
#
# 1.  **`swapKeysAndValuesRobust`**:
#     *   **`inputMap |> Map.toSeq`**: Converts the `Map` into a `seq<('Key * 'Value)>` (a sequence of key-value tuples). This is often the first step when performing transformations on a `Map` in F#.
#     *   **`|> Seq.groupBy snd`**: This is the core of handling duplicates. It groups the sequence of tuples based on their *second* element (`snd`), which is the original `Value`. The result is a `seq<('Value * seq<'Key * 'Value>)>`. Each item in this sequence is a tuple where the first element is a unique original `Value`, and the second element is a sequence of all `('Key * 'Value)` pairs that shared that original `Value`.
#     *   **`|> Seq.map (fun (oldValue, seqOfPairs) -> ...)`**: We then iterate over these groups.
#         *   `oldValue` is the unique original value (which will become the new key).
#         *   `seqOfPairs` is the sequence of `('Key * 'Value)` tuples that had this `oldValue`.
#         *   **`let originalKeys = seqOfPairs |> Seq.map fst |> Seq.toList`**: From `seqOfPairs`, we extract only the *first* element (`fst`) of each tuple (which is the original `Key`), and collect them into a `list<'Key>`.
#         *   **`(oldValue, originalKeys)`**: This creates the new key-value pair for our result map: the `oldValue` (now the key) mapped to the `list` of `originalKeys`.
#     *   **`|> Map.ofSeq`**: Finally, this converts the sequence of new `('Value * list<'Key>)` pairs back into a `Map<'Value, list<'Key>>`.
#
# 2.  **`swapKeysAndValuesSimple`**:
#     *   This function is much simpler because it doesn't explicitly handle duplicate values.
#     *   **`inputMap |> Map.toSeq`**: Same as before, converts to a sequence of pairs.
#     *   **`|> Seq.map (fun (key, value) -> (value, key))`**: This just flips each `(key, value)` tuple to `(value, key)`.
#     *   **`|> Map.ofSeq`**: When `Map.ofSeq` encounters duplicate keys (i.e., if multiple original keys mapped to the same value), it will simply overwrite the previous entry. This means only the last `(value, key)` pair encountered for a given `value` will be present in the final map, leading to potential data loss.
#
# Choose the `swapKeysAndValuesRobust` function for a safer, more functionally complete solution that preserves all information.
